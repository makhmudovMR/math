# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x_ = np.linspace(0,10)
f = x_ ** 2
plt.grid()
plt.plot(x_, f)

# %%
x_ = np.linspace(0,10)
f = 2 * x_
plt.grid()
plt.plot(x_, f)
